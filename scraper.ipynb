# %%
import requests
import time, os
import re

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys

# %%
objects_list = []

# %%
class BaseInfo:
    def __init__(self, city='None', district='None', neighborhood='None', prop_type='None', rooms='None', living_room='None', price='None'):
        self.city = city 
        self.district = district
        self.neighborhood = neighborhood
        self.prop_type = prop_type
        self.rooms = rooms
        self.living_room = living_room
        self.price = price
        
    def print_info(self):
        print('city:{} district:{} neighborhood:{} prop_type:{} rooms:{} living_room:{} price:{}'.format(self.city, self.district,
                                                                                                self.neighborhood,self.prop_type,
                                                                                                self.rooms, self.living_room, self.price))
        
class Advertisement:
    def __init__(self, base_info, last_edit='None', area='None', prop_floor='None', building_age='None',
                 heating_type='None', building_floors='None', credit_availability='None', furniture_availability='None',
                 bathrooms='None', building_type='None', building_status='None', usage_status='None', deed='None', dues='None',
                 swap='None', student_single='None', facade='None', fuel_type='None'):
        self.base_info = base_info
        self.last_edit = last_edit
        self.area = area
        self.building_age = building_age
        self.prop_floor = prop_floor
        self.heating_type = heating_type
        self.building_floors = building_floors
        self.credit_availability = credit_availability
        self.furniture_availability = furniture_availability
        self.bathrooms = bathrooms
        self.building_type = building_type
        self.building_status = building_status
        self.usage_status = usage_status
        self.deed = deed
        self.dues = dues
        self.swap = swap
        self.student_single = student_single
        self.facade = facade
        self.fuel_type = fuel_type
        
    def print_info(self):
        self.base_info.print_info()
        print('last_edit:{} area:{} prop_floor:{} building_age:{} heating_type:{} building_floors:{} credit_availability:{} furniture_availability:{} bathrooms:{} building_type:{} building_status:{} usage_status:{} deed:{} dues:{} swap:{} student_single:{} facade:{} fuel_type:{}'.format(
                  self.last_edit, self.area, self.prop_floor, self.building_age, self.heating_type,
                  self.building_floors, self.credit_availability, self.furniture_availability, self.bathrooms, self.building_type,
                  self.building_status, self.usage_status, self.deed, self.dues, self.swap, self.student_single, self.facade,
                  self.fuel_type))

# %%
chromedriver = './app/chromedriver' # path to the chromedriver executable
os.environ['webdriver.chrome.driver'] = chromedriver

# %%
base_url = 'https://www.hurriyetemlak.com'
istanbul_sell_url = '/istanbul-satilik'

# %%
def parse_base_inf(ul_short_info_list, price):
    i = 1
    city = ''
    district = ''
    neighborhood = ''
    prop_type = ''
    rooms = ''
    living_room = ''
    for li in ul_short_info_list.find_all('li'):
        if(i==1):
            city = li.text.strip()
        elif(i==2):
            district = li.text.strip()
        elif(i==3):
            neighborhood = li.text.strip()
        elif(i==5):
            prop_type = li.text.strip()
        elif(i==6):
            value = li.text.strip()
            rooms, living_room = value.split('+', 1)
        i = i + 1
    return BaseInfo(city, district, neighborhood, prop_type, rooms.strip(), living_room.strip(), price.text.strip())

# %%
def parse_adv_info(ul_adv_info_list, base_info):
    last_edit = ''
    area = ''
    prop_floor = ''
    building_age = ''
    heating_type = ''
    building_floors = ''
    credit_availability = ''
    furniture_availability = ''
    bathrooms = ''
    building_type = ''
    building_status = ''
    usage_status = ''
    deed = ''
    dues = ''
    swap = ''
    student_single = ''
    facade = ''
    fuel_type = ''
    if ul_adv_info_list:
        for li in ul_adv_info_list.find_all('li'):
            param = li.find_all('span')
            param_type = param[0].text.strip()
            param_value = param[1].text.strip()
            if(param_type=='Son Güncelleme Tarihi'):
                last_edit = param_value
            elif(param_type=='Brüt / Net M2'):
                area = param_value
            elif(param_type=='Bulunduğu Kat'):
                prop_floor = param_value
            elif(param_type=='Bina Yaşı'):
                building_age = param_value
            elif(param_type=='Isınma Tipi'):
                heating_type = param_value
            elif(param_type=='Kat Sayısı'):
                building_floors = param_value
            elif(param_type=='Krediye Uygunluk'):
                credit_availability = param_value
            elif(param_type=='Eşya Durumu'):
                furniture_availability = param_value
            elif(param_type=='Banyo Sayısı'):
                bathrooms = param_value
            elif(param_type=='Yapı Tipi'):
                building_type = param_value
            elif(param_type=='Yapının Durumu'):
                building_status = param_value
            elif(param_type=='Kullanım Durumu'):
                usage_status = param_value
            elif(param_type=='Tapu Durumu'):
                deed = param_value
            elif(param_type=='Aidat'):
                dues = param_value
            elif(param_type=='Takas'):
                swap = param_value
            elif(param_type=='Öğrenciye / Bekara'):
                student_single = param_value
            elif(param_type=='Cephe'):
                facade = param_value
            elif(param_type=='Yakıt Tipi'):
                fuel_type = param_value
    
    return Advertisement(base_info, last_edit, area, prop_floor, building_age, heating_type,
                        building_floors, credit_availability, furniture_availability, bathrooms, building_type, building_status,
                        usage_status, deed, dues, swap, student_single, facade, fuel_type)

# %%
def get_house_info(page_source):
    global objects_list
    soup = BeautifulSoup(page_source, 'html5lib')
    price = soup.find('p', {'class': 'price'})
    ul_short_info_list = soup.find('ul', {'class': 'short-info-list'})
    ul_adv_info_list = soup.find('ul', {'class': 'adv-info-list'})
    if ul_short_info_list and price:
        base_info = parse_base_inf(ul_short_info_list, price)
        if ul_adv_info_list:
            full_adv_info = parse_adv_info(ul_adv_info_list, base_info)
            objects_list.append(full_adv_info)

# %%
def get_house_page(props_list):
    driver = webdriver.Chrome(chromedriver)
    for a in props_list:
        link = base_url + str(a['href'])
        driver.get(link)
        get_house_info(driver.page_source)
        
    driver.close()

# %%
def get_houses_list(page_source):
    soup = BeautifulSoup(page_source, 'html5lib')
    props_list = soup.find_all('a', {'class': 'img-link'})
    
    for a in props_list:
        if a['href'].startswith('https:'):
            props_list.remove(a)
    
    get_house_page(props_list)

# %%
def get_pages():
    driver = webdriver.Chrome(chromedriver)
    for i in range(1201,1401):
        page = '/?page={}'.format(i)
        link = base_url + istanbul_sell_url + page
        driver.get(link)
        # driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        get_houses_list(driver.page_source)

# %%
get_pages()

# %%
for prop in objects_list:
    prop.print_info()
    print('--------------------------------')
# Out:
# city:İstanbul district:Eyüpsultan neighborhood:Akşemsettin prop_type:Daire rooms:4 living_room:2 price:670.000 TL
# last_edit:9 Gün Önce area:210 m2 prop_floor:4. Kat building_age:7 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:35 TL swap:Hayır student_single: facade:Doğu fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Silivri neighborhood:Selimpaşa prop_type:Çiftlik Evi rooms:15 living_room:2 price:17.500.000 TL
# last_edit:9 Gün Önce area:850 m2 prop_floor:Villa Katı building_age:25 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:5 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Arsa dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Silivri neighborhood:Ortaköy prop_type:Villa rooms:12 living_room:1 price:4.000.000 TL
# last_edit:7 Gün Önce area:500 m2 prop_floor:Villa Katı building_age:15 Yaşında heating_type:Merkezi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Maltepe neighborhood:Aydınevler prop_type:Daire rooms:2 living_room:1 price:390.000 TL
# last_edit:7 Gün Önce area:90 m2 prop_floor:2. Kat building_age:Sıfır Bina heating_type:Merkezi (Pay Ölçer) building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:120 TL swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Ayvansaray prop_type:Müstakil Ev rooms:2 living_room:2 price:320.000 TL
# last_edit:34 Gün Önce area:135 m2 prop_floor: building_age:35 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Emirgan prop_type:Daire rooms:4 living_room:2 price:13.500.000 TL
# last_edit:Dün area:305 m2 prop_floor:2. Kat building_age:35 Yaşında heating_type:Merkezi building_floors:4 Katlı credit_availability:Bilinmiyor furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Siyavuşpaşa prop_type:Daire rooms:2 living_room:1 price:350.000 TL
# last_edit:Dün area:90 m2 prop_floor:2. Kat building_age:25 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues:25 TL swap:Hayır student_single: facade:Batı fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Bozkurt prop_type:Daire rooms:2 living_room:1 price:560.000 TL
# last_edit:5 Gün Önce area:95 m2 prop_floor: building_age:35 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Tarabya prop_type:Daire rooms:3 living_room:1 price:5.250.000 TL
# last_edit:22 Gün Önce area:155 m2 prop_floor:1. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Karagümrük prop_type:Bina rooms:4 living_room:0 price:1.100.000 TL
# last_edit:22 Gün Önce area:97 m2 prop_floor:Ara Kat building_age:50 Yaşında heating_type:Kombi building_floors:2 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status:İkinci El usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Dikilitaş prop_type:Daire rooms:2 living_room:1 price:4.200.000 TL
# last_edit:Dün area:142 m2 prop_floor:11. Kat building_age:10 Yaşında heating_type:Merkezi building_floors:23 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status:Boş deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:İcadiye prop_type:Daire rooms:2 living_room:1 price:480.000 TL
# last_edit:19 Gün Önce area:85 m2 prop_floor:4. Kat building_age:26 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Arsa dues:30 TL swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Maltepe neighborhood:Cevizli prop_type:Daire rooms:3 living_room:1 price:1.190.000 TL
# last_edit:10 Gün Önce area:140 m2 prop_floor:15. Kat building_age:Sıfır Bina heating_type:Merkezi (Pay Ölçer) building_floors:16 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Yıldız prop_type:Daire rooms:3 living_room:1 price:2.500.000 TL
# last_edit:Bugün area:135 m2 prop_floor:7. Kat building_age:30 Yaşında heating_type:Kombi building_floors:7 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:30 TL swap: student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Avcılar neighborhood:Cihangir prop_type:Daire rooms:3 living_room:1 price:230.000 TL
# last_edit:7 Gün Önce area:145 m2 prop_floor:1. Kat building_age:20 Yaşında heating_type:Kombi building_floors:7 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status: deed: dues:20 TL swap:Evet student_single:Evet facade:Kuzey, fuel_type:
# --------------------------------
# city:İstanbul district:Beylikdüzü neighborhood:Adnan Kahveci prop_type:Daire rooms:3 living_room:2 price:485.000 TL
# last_edit:7 Gün Önce area:140 m2 prop_floor:3. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Caddebostan prop_type:Daire rooms:4 living_room:1 price:1.500.000 TL
# last_edit:7 Gün Önce area:200 m2 prop_floor:9. Kat building_age:26 Yaşında heating_type:Merkezi building_floors:9 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap: student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Suadiye prop_type:Daire rooms:3 living_room:1 price:1.750.000 TL
# last_edit:23 Gün Önce area:130 m2 prop_floor:7. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Zekeriyaköy prop_type:Villa rooms:5 living_room:1 price:12.350.000 TL
# last_edit:11 Gün Önce area:480 m2 prop_floor:3. Kat building_age:4 Yaşında heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:5 building_type: building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:3.000 TL swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Emirgan prop_type:Villa rooms:3 living_room:1 price:7.000.000 TL
# last_edit:5 Gün Önce area:180 m2 prop_floor: building_age:28 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Siyavuşpaşa prop_type:Daire rooms:3 living_room:1 price:435.000 TL
# last_edit:5 Gün Önce area:120 m2 prop_floor:4. Kat building_age:32 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues:40 TL swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Suadiye prop_type:Daire rooms:2 living_room:1 price:1.245.000 TL
# last_edit:7 Gün Önce area:118 m2 prop_floor:Bahçe Katı building_age:30 Yaşında heating_type:Merkezi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed: dues: swap: student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Maden prop_type:Daire rooms:3 living_room:1 price:1.900.000 TL
# last_edit:Bugün area:210 m2 prop_floor:2. Kat building_age:3 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status: deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Siyavuşpaşa prop_type:Daire rooms:2 living_room:1 price:365.000 TL
# last_edit:9 Gün Önce area:100 m2 prop_floor:3. Kat building_age:25 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status: usage_status:Ev Sahibi Oturuyor deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Maltepe neighborhood:Altıntepe prop_type:Daire rooms:1 living_room:1 price:395.000 TL
# last_edit:24 Gün Önce area:70 m2 prop_floor:Bahçe Katı building_age:2 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:60 TL swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Selami Ali prop_type:Daire rooms:3 living_room:1 price:650.000 TL
# last_edit:3 Gün Önce area:110 m2 prop_floor:3. Kat building_age:30 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sancaktepe neighborhood:Merve prop_type:Daire rooms:3 living_room:1 price:430.000 TL
# last_edit:7 Gün Önce area:150 m2 prop_floor:4. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:30 TL swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Ayazağa prop_type:Daire rooms:2 living_room:1 price:2.500.000 TL
# last_edit:26 Gün Önce area:130 m2 prop_floor:18. Kat building_age:5 Yaşında heating_type:Merkezi building_floors:20 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Levazım prop_type:Daire rooms:3 living_room:1 price:2.100.000 TL
# last_edit:25 Gün Önce area:165 m2 prop_floor:2. Kat building_age:33 Yaşında heating_type:Merkezi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Suadiye prop_type:Daire rooms:3 living_room:1 price:2.975.000 TL
# last_edit:6 Gün Önce area:175 m2 prop_floor:4. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:11 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Selami Ali prop_type:Daire rooms:2 living_room:1 price:420.000 TL
# last_edit:32 Gün Önce area:90 m2 prop_floor:1. Kat building_age:20 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat İrtifakı dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Eyüpsultan neighborhood:Merkez prop_type:Daire rooms:2 living_room:1 price:275.000 TL
# last_edit:4 Gün Önce area:100 m2 prop_floor:Bahçe Katı building_age:10 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues:20 swap: student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Akat prop_type:Villa rooms:6 living_room:2 price:12.950.000 TL
# last_edit:18 Gün Önce area:350 m2 prop_floor:Villa Katı building_age:45 Yaşında heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Kagir building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap: student_single: facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Küçükçekmece neighborhood:Sultan Murat prop_type:Daire rooms:2 living_room:1 price:550.000 TL
# last_edit:20 Gün Önce area:100 m2 prop_floor:2. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Gaziosmanpaşa neighborhood:Yeni Mahalle prop_type:Daire rooms:2 living_room:1 price:208.000 TL
# last_edit:Dün area:110 m2 prop_floor:Ara Kat building_age:19 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Doğu fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bayrampaşa neighborhood:Yıldırım prop_type:Daire rooms:3 living_room:2 price:770.000 TL
# last_edit:5 Gün Önce area:200 m2 prop_floor:5. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat İrtifakı dues: swap:Evet student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:İskenderpaşa prop_type:Daire rooms:2 living_room:1 price:520.000 TL
# last_edit:17 Gün Önce area:85 m2 prop_floor:3. Kat building_age:15 Yaşında heating_type:Merkezi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues:70 TL swap:Hayır student_single: facade:Kuzey fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Atikali prop_type:Daire rooms:1 living_room:1 price:2.975.000 TL
# last_edit:28 Gün Önce area:400 m2 prop_floor:Giriş Katı building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Evet student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Başakşehir neighborhood:Bahçeşehir 2. Kısım prop_type:Daire rooms:3 living_room:1 price:1.350.000 TL
# last_edit:25 Gün Önce area:175 m2 prop_floor:8. Kat building_age:19 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:14 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Çekmeköy neighborhood:Mimar Sinan prop_type:Villa rooms:5 living_room:1 price:3.980.000 TL
# last_edit:12 Gün Önce area:450 m2 prop_floor:3. Kat building_age:22 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed:Kat Mülkiyeti dues:1.150 TL swap: student_single: facade:Güney, fuel_type:
# --------------------------------
# city:İstanbul district:Esenyurt neighborhood:Yeşilkent prop_type:Daire rooms:2 living_room:1 price:275.000 TL
# last_edit:11 Gün Önce area:95 m2 prop_floor:3. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Evet student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bağcılar neighborhood:Yavuz Selim prop_type:Daire rooms:2 living_room:1 price:310.000 TL
# last_edit:7 Gün Önce area:85 m2 prop_floor: building_age:7 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Bostancı prop_type:Daire rooms:3 living_room:1 price:625.000 TL
# last_edit:4 Gün Önce area:145 m2 prop_floor:5. Kat building_age:35 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues:100 TL swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Suadiye prop_type:Daire rooms:3 living_room:1 price:745.000 TL
# last_edit:10 Gün Önce area:125 m2 prop_floor:Bahçe Katı building_age:36 Yaşında heating_type:Merkezi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues: swap: student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Bahçelievler prop_type:Daire rooms:3 living_room:1 price:900.000 TL
# last_edit:14 Gün Önce area:120 m2 prop_floor:1. Kat building_age:30 Yaşında heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Merdivenköy prop_type:Daire rooms:3 living_room:1 price:695.000 TL
# last_edit:11 Gün Önce area:135 m2 prop_floor:6. Kat building_age:35 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Levent prop_type:Residence rooms:4 living_room:1 price:8.400.000 TL
# last_edit:27 Gün Önce area:318 m2 prop_floor:1. Kat building_age:15 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:16 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:3 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Zeytinburnu neighborhood:Kazlıçeşme prop_type:Residence rooms:3 living_room:1 price:5.500.000 TL
# last_edit:55 Gün Önce area:164 m2 prop_floor:6. Kat building_age:2 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:25 Katlı credit_availability:Uygun furniture_availability:Eşyalı bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:720 TL swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Büyükçekmece neighborhood:Türkoba prop_type:Villa rooms:4 living_room:1 price:3.850.000 TL
# last_edit:6 Gün Önce area:450 m2 prop_floor:Villa Katı building_age:11 Yaşında heating_type:Kombi building_floors:2 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:450 TL swap:Hayır student_single: facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Pendik neighborhood:Batı prop_type:Daire rooms:3 living_room:2 price:1.450.000 TL
# last_edit:7 Gün Önce area:175 m2 prop_floor:6. Kat building_age:1 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Dikilitaş prop_type:Daire rooms:2 living_room:1 price:690.000 TL
# last_edit:Bugün area:90 m2 prop_floor:Yüksek Giriş building_age:20 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat İrtifakı dues:30 TL swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kağıthane neighborhood:Gürsel prop_type:Daire rooms:2 living_room:1 price:370.000 TL
# last_edit:20 Gün Önce area:100 m2 prop_floor: building_age:20 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Bakırköy neighborhood:Şenlikköy prop_type:Daire rooms:3 living_room:1 price:2.750.000 TL
# last_edit:5 Gün Önce area:150 m2 prop_floor:Bahçe Katı building_age:Sıfır Bina heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap: student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Büyükçekmece neighborhood:Atatürk prop_type:Daire rooms:2 living_room:1 price:350.000 TL
# last_edit:29 Gün Önce area:85 m2 prop_floor:Bahçe Katı building_age:1 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Belirtilmemiş deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Bahçelievler prop_type:Daire rooms:2 living_room:1 price:760.000 TL
# last_edit:10 Gün Önce area:100 m2 prop_floor:Bahçe Katı building_age:Sıfır Bina heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Çekmeköy neighborhood:Merkez prop_type:Daire rooms:1 living_room:1 price:300.000 TL
# last_edit:25 Gün Önce area:65 m2 prop_floor:Yüksek Giriş building_age:5 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Belirtilmemiş deed:Kat İrtifakı dues:50 TL swap:Evet student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Zafer prop_type:Daire rooms:2 living_room:1 price:300.000 TL
# last_edit:20 Gün Önce area:85 m2 prop_floor:Yüksek Giriş building_age:9 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bağcılar neighborhood:15 Temmuz prop_type:Daire rooms:3 living_room:1 price:520.000 TL
# last_edit:Bugün area:130 m2 prop_floor:2. Kat building_age:15 Yaşında heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed: dues: swap:Hayır student_single: facade:Batı fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Ptt Evleri prop_type:Müstakil Ev rooms:8 living_room:4 price:3.645.000 TL
# last_edit:10 Gün Önce area:450 m2 prop_floor:Villa Katı building_age:20 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:4 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Arsa dues: swap:Evet student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Silivri neighborhood:Selimpaşa prop_type:Daire rooms:2 living_room:1 price:325.000 TL
# last_edit:31 Gün Önce area:115 m2 prop_floor: building_age:8 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Cumhuriyet prop_type:Daire rooms:2 living_room:1 price:185.000 TL
# last_edit:12 Gün Önce area:90 m2 prop_floor:Bahçe Katı building_age:6 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues: swap: student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Soğanlı prop_type:Daire rooms:3 living_room:1 price:285.000 TL
# last_edit:5 Gün Önce area:110 m2 prop_floor:Bahçe Katı building_age:13 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Avcılar neighborhood:Denizköşkler prop_type:Daire rooms:5 living_room:2 price:800.000 TL
# last_edit:7 Gün Önce area:230 m2 prop_floor:4. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:40 TL swap:Evet student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Arnavutköy neighborhood:Boğazköy İstiklal prop_type:Villa rooms:4 living_room:3 price:2.550.000 TL
# last_edit:6 Gün Önce area:374 m2 prop_floor:Villa Katı building_age:7 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:3 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:300 TL swap: student_single: facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beykoz neighborhood:Mahmutşevketpaşa prop_type:Çiftlik Evi rooms:5 living_room:2 price:11.000.000 TL
# last_edit:24 Gün Önce area:400 m2 prop_floor:2. Kat building_age:18 Yaşında heating_type:Kombi building_floors:2 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type: building_status: usage_status: deed:Kat Mülkiyeti dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Cumhuriyet prop_type:Daire rooms:2 living_room:1 price:335.000 TL
# last_edit:Bugün area:100 m2 prop_floor:Yüksek Giriş building_age:13 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beyoğlu neighborhood:Hüseyinağa prop_type:Daire rooms:1 living_room:1 price:565.000 TL
# last_edit:18 Gün Önce area:75 m2 prop_floor:3. Kat building_age:100 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Maltepe neighborhood:İdealtepe prop_type:Daire rooms:1 living_room:1 price:229.000 TL
# last_edit:8 Gün Önce area:70 m2 prop_floor:Bahçe Katı building_age:8 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues:50 TL swap:Hayır student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Esenler neighborhood:Mimar Sinan prop_type:Daire rooms:2 living_room:1 price:250.000 TL
# last_edit:14 Gün Önce area:90 m2 prop_floor:Bahçe Katı building_age:4 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Eyüpsultan neighborhood:Göktürk Merkez prop_type:Villa rooms:5 living_room:2 price:19.000.000 TL
# last_edit:5 Gün Önce area:450 m2 prop_floor: building_age:18 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kartal neighborhood:Hürriyet prop_type:Daire rooms:2 living_room:1 price:435.000 TL
# last_edit:12 Gün Önce area:95 m2 prop_floor:8. Kat building_age:3 Yaşında heating_type:Kombi building_floors:9 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status: usage_status:Kiracı Oturuyor deed:Kat İrtifakı dues:50 TL swap: student_single: facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Güngören neighborhood:Güneştepe prop_type:Daire rooms:3 living_room:1 price:365.000 TL
# last_edit:14 Gün Önce area:125 m2 prop_floor:4. Kat building_age:25 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Molla Gürani prop_type:Daire rooms:2 living_room:1 price:550.000 TL
# last_edit:10 Gün Önce area:110 m2 prop_floor:1. Kat building_age:32 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues:30 TL swap:Hayır student_single:Evet facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Soğanlı prop_type:Daire rooms:2 living_room:1 price:330.000 TL
# last_edit:4 Gün Önce area:100 m2 prop_floor:Yüksek Giriş building_age:25 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Esenler neighborhood:Fatih prop_type:Daire rooms:2 living_room:1 price:270.000 TL
# last_edit:5 Gün Önce area:80 m2 prop_floor:Bahçe Katı building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:20 TL swap:Evet student_single:Evet facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Başakşehir neighborhood:Güvercintepe prop_type:Daire rooms:2 living_room:1 price:965.000 TL
# last_edit:29 Gün Önce area:154 m2 prop_floor:10. Kat building_age:4 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:16 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Merkez prop_type:Daire rooms:2 living_room:1 price:750.000 TL
# last_edit:18 Gün Önce area:130 m2 prop_floor:Bahçe Katı building_age:Sıfır Bina heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed: dues: swap:Hayır student_single:Evet facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beylikdüzü neighborhood:Yakuplu prop_type:Daire rooms:1 living_room:1 price:330.000 TL
# last_edit:24 Gün Önce area:95 m2 prop_floor:9. Kat building_age:8 Yaşında heating_type:Kombi building_floors:9 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat İrtifakı dues:200 swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Caddebostan prop_type:Daire rooms:4 living_room:1 price:3.000.000 TL
# last_edit:25 Gün Önce area:185 m2 prop_floor:3. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beylikdüzü neighborhood:Barış prop_type:Daire rooms:1 living_room:1 price:270.000 TL
# last_edit:14 Gün Önce area:85 m2 prop_floor:2. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed: dues: swap:Evet student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Seyyid Ömer prop_type:Daire rooms:2 living_room:1 price:410.000 TL
# last_edit:4 Gün Önce area:75 m2 prop_floor:1. Kat building_age:25 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues:35 TL swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Göztepe prop_type:Daire rooms:3 living_room:1 price:1.750.000 TL
# last_edit:14 Gün Önce area:145 m2 prop_floor:4. Kat building_age:4 Yaşında heating_type:Kombi building_floors:9 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Eyüpsultan neighborhood:Çırçır prop_type:Daire rooms:2 living_room:1 price:350.000 TL
# last_edit:8 Gün Önce area:85 m2 prop_floor:Kot 1 building_age:Sıfır Bina heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Suadiye prop_type:Daire rooms:2 living_room:1 price:595.000 TL
# last_edit:7 Gün Önce area:100 m2 prop_floor:Yüksek Giriş building_age:32 Yaşında heating_type:Merkezi building_floors:7 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Maltepe neighborhood:Fındıklı prop_type:Daire rooms:4 living_room:2 price:540.000 TL
# last_edit:20 Gün Önce area:200 m2 prop_floor:4. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:60 TL swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Hürriyet prop_type:Daire rooms:1 living_room:1 price:330.000 TL
# last_edit:Bugün area:60 m2 prop_floor:Yüksek Giriş building_age:2 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bakırköy neighborhood:Yeşilyurt prop_type:Daire rooms:4 living_room:2 price:4.200.000 TL
# last_edit:51 Gün Önce area:270 m2 prop_floor:5. Kat building_age:2 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Arnavutköy neighborhood:İslambey prop_type:Daire rooms:3 living_room:2 price:310.000 TL
# last_edit:Bugün area:185 m2 prop_floor: building_age:3 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Küçükçekmece neighborhood:Atakent prop_type:Daire rooms:2 living_room:1 price:995.000 TL
# last_edit:16 Gün Önce area:130 m2 prop_floor:Bahçe Katı building_age:2 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Muradiye prop_type:Daire rooms:1 living_room:1 price:375.000 TL
# last_edit:16 Gün Önce area:60 m2 prop_floor:5. Kat building_age:26 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat İrtifakı dues:50 TL swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Teşvikiye prop_type:Daire rooms:5 living_room:1 price:11.000.000 TL
# last_edit:25 Gün Önce area:270 m2 prop_floor:Giriş Katı building_age:86 Yaşında heating_type:Merkezi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Kagir building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Çekmeköy neighborhood:Ekşioğlu prop_type:Daire rooms:2 living_room:1 price:352.000 TL
# last_edit:7 Gün Önce area:94 m2 prop_floor:4. Kat building_age:Sıfır Bina heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed: dues: swap:Evet student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Büyükçekmece neighborhood:Pınartepe prop_type:Daire rooms:3 living_room:1 price:1.100.000 TL
# last_edit:4 Gün Önce area:194 m2 prop_floor:3. Kat building_age:10 Yaşında heating_type:Kombi building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat İrtifakı dues:340 TL swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kağıthane neighborhood:Talatpaşa prop_type:Daire rooms:1 living_room:1 price:485.000 TL
# last_edit:7 Gün Önce area:76 m2 prop_floor:3. Kat building_age:9 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed: dues:420 TL swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Güngören neighborhood:Güven prop_type:Daire rooms:2 living_room:1 price:350.000 TL
# last_edit:4 Gün Önce area:120 m2 prop_floor:5. Kat building_age:31 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kağıthane neighborhood:Harmantepe prop_type:Daire rooms:3 living_room:1 price:292.000 TL
# last_edit:10 Gün Önce area:125 m2 prop_floor:2. Kat building_age:26 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status: usage_status: deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bahçelievler neighborhood:Cumhuriyet prop_type:Daire rooms:2 living_room:1 price:330.000 TL
# last_edit:14 Gün Önce area:105 m2 prop_floor:2. Kat building_age:29 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kağıthane neighborhood:Telsizler prop_type:Daire rooms:2 living_room:1 price:315.000 TL
# last_edit:10 Gün Önce area:90 m2 prop_floor:1. Kat building_age:20 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status: usage_status: deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Gaziosmanpaşa neighborhood:Karadeniz prop_type:Daire rooms:3 living_room:1 price:347.000 TL
# last_edit:15 Gün Önce area:120 m2 prop_floor:2. Kat building_age:20 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat İrtifakı dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# ...
# --------------------------------
# city:İstanbul district:Küçükçekmece neighborhood:Yeşilova prop_type:Daire rooms:2 living_room:1 price:229.000 TL
# last_edit:16 Gün Önce area:70 m2 prop_floor:Bahçe Katı building_age:5 Yaşında heating_type:Kombi building_floors:2 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap: student_single:Evet facade:Doğu, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Çengelköy prop_type:Daire rooms:1 living_room:1 price:1.099.000 TL
# last_edit:21 Gün Önce area:93 m2 prop_floor: building_age:2 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Eyüpsultan neighborhood:Sakarya prop_type:Daire rooms:1 living_room:1 price:200.000 TL
# last_edit:20 Gün Önce area:60 m2 prop_floor:Kot 1 building_age:3 Yaşında heating_type:Kombi building_floors:6 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:30 TL swap:Hayır student_single: facade:Kuzey fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Küçükçekmece neighborhood:Yeşilova prop_type:Daire rooms:4 living_room:1 price:550.000 TL
# last_edit:12 Gün Önce area:200 m2 prop_floor:5. Kat building_age:25 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Arsa dues:25 TL swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bağcılar neighborhood:Yenimahalle prop_type:Daire rooms:2 living_room:1 price:370.000 TL
# last_edit:8 Gün Önce area:115 m2 prop_floor:1. Kat building_age:14 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues: swap: student_single: facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Esenyurt neighborhood:Zafer prop_type:Daire rooms:3 living_room:1 price:600.000 TL
# last_edit:33 Gün Önce area:171 m2 prop_floor:11. Kat building_age:Sıfır Bina heating_type:Merkezi (Pay Ölçer) building_floors:17 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap: student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Silivrikapı prop_type:Daire rooms:3 living_room:1 price:610.000 TL
# last_edit:69 Gün Önce area:115 m2 prop_floor:1. Kat building_age:30 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed: dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Başakşehir neighborhood:Bahçeşehir 2. Kısım prop_type:Villa rooms:5 living_room:2 price:1.350.000 TL
# last_edit:Dün area:360 m2 prop_floor:Villa Katı building_age:15 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Esenyurt neighborhood:Zafer prop_type:Daire rooms:3 living_room:1 price:580.000 TL
# last_edit:36 Gün Önce area:160 m2 prop_floor: building_age:8 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Güngören neighborhood:Akıncılar prop_type:Daire rooms:3 living_room:1 price:340.000 TL
# last_edit:5 Gün Önce area:120 m2 prop_floor: building_age:30 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues:25 TL swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kadıköy neighborhood:Bostancı prop_type:Daire rooms:4 living_room:1 price:2.000.000 TL
# last_edit:12 Gün Önce area:190 m2 prop_floor:3. Kat building_age:Sıfır Bina heating_type:Merkezi (Pay Ölçer) building_floors:11 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Ataşehir neighborhood:Kayışdağı prop_type:Bina rooms:12 living_room:4 price:2.150.000 TL
# last_edit:2 Gün Önce area:600 m2 prop_floor:Kot 1 building_age:30 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:4 building_type:Betonarme building_status:İkinci El usage_status:Belirtilmemiş deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Eyüpsultan neighborhood:Güzeltepe prop_type:Daire rooms:2 living_room:1 price:285.000 TL
# last_edit:26 Gün Önce area:70 m2 prop_floor:Yüksek Giriş building_age:2 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Belirtilmemiş deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Yayla prop_type:Daire rooms:2 living_room:1 price:310.000 TL
# last_edit:34 Gün Önce area:90 m2 prop_floor:Yüksek Giriş building_age:15 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status:Kiracı Oturuyor deed: dues: swap:Evet student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Kağıthane neighborhood:Çeliktepe prop_type:Daire rooms:2 living_room:1 price:390.000 TL
# last_edit:Bugün area:80 m2 prop_floor:Bahçe Katı building_age:Sıfır Bina heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues:50 TL swap:Hayır student_single:Evet facade:Kuzey, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Avcılar neighborhood:Mustafa Kemal Paşa prop_type:Bina rooms:12 living_room:6 price:1.800.000 TL
# last_edit:Bugün area:1.060 m2 prop_floor:4. Kat building_age:18 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:6 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Arsa dues:30 TL swap:Evet student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Ulus prop_type:Daire rooms:3 living_room:1 price:7.050.000 TL
# last_edit:Bugün area:210 m2 prop_floor:3. Kat building_age:16 Yaşında heating_type:Merkezi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status: deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Gaziosmanpaşa neighborhood:Sarıgöl prop_type:Daire rooms:3 living_room:1 price:400.000 TL
# last_edit:34 Gün Önce area:125 m2 prop_floor:Kot 3 building_age:4 Yaşında heating_type:Kombi building_floors:9 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed:Kat Mülkiyeti dues:75 TL swap:Evet student_single:Evet facade:Güney fuel_type:
# --------------------------------
# city:İstanbul district:Küçükçekmece neighborhood:Mehmet Akif prop_type:Daire rooms:2 living_room:1 price:210.000 TL
# last_edit:9 Gün Önce area:120 m2 prop_floor:3. Kat building_age:20 Yaşında heating_type:Kombi building_floors:7 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed: dues: swap:Hayır student_single: facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Ulus prop_type:Daire rooms:3 living_room:1 price:7.000.000 TL
# last_edit:Bugün area:210 m2 prop_floor:3. Kat building_age:16 Yaşında heating_type:Merkezi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status: deed: dues: swap: student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Beşiktaş neighborhood:Ortaköy prop_type:Daire rooms:1 living_room:1 price:530.000 TL
# last_edit:6 Gün Önce area:80 m2 prop_floor:Bahçe Katı building_age:2 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:Sıfır usage_status:Boş deed:Kat Mülkiyeti dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Sarıyer neighborhood:Zekeriyaköy prop_type:Villa rooms:4 living_room:1 price:7.700.000 TL
# last_edit:9 Gün Önce area:350 m2 prop_floor:Villa Katı building_age:Sıfır Bina heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:3 building_type:Betonarme building_status:Yapım Aşamasında usage_status:Boş deed:Arsa dues: swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Fatih neighborhood:Seyyid Ömer prop_type:Daire rooms:2 living_room:1 price:275.000 TL
# last_edit:20 Gün Önce area:75 m2 prop_floor:4. Kat building_age:30 Yaşında heating_type:Kombi building_floors:4 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat İrtifakı dues:20 TL swap:Hayır student_single: facade:Güney, fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Adalar neighborhood:Burgazada prop_type:Daire rooms:3 living_room:1 price:1.200.000 TL
# last_edit:15 Gün Önce area:110 m2 prop_floor: building_age:30 Yaşında heating_type:Belirtilmemiş building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Sancaktepe neighborhood:Eyüp Sultan prop_type:Daire rooms:1 living_room:1 price:350.000 TL
# last_edit:19 Gün Önce area:60 m2 prop_floor:6. Kat building_age:1 Yaşında heating_type:Merkezi (Pay Ölçer) building_floors:7 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat Mülkiyeti dues:250 TL swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Bahçelievler prop_type:Daire rooms:3 living_room:2 price:1.500.000 TL
# last_edit:10 Gün Önce area:200 m2 prop_floor:Çatı Katı building_age:8 Yaşında heating_type:Kombi building_floors:3 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:3 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Mecidiyeköy prop_type:Daire rooms:2 living_room:1 price:385.000 TL
# last_edit:24 Gün Önce area:85 m2 prop_floor:1. Kat building_age:15 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun değil furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Arsa dues:35 TL swap:Hayır student_single:Evet facade: fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Ataşehir neighborhood:Yeni Sahra prop_type:Daire rooms:1 living_room:1 price:305.000 TL
# last_edit:21 Gün Önce area:60 m2 prop_floor:Giriş Katı building_age:10 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Kiracı Oturuyor deed:Kat İrtifakı dues:50 TL swap:Evet student_single:Evet facade:Kuzey fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Şişli neighborhood:Fulya prop_type:Daire rooms:2 living_room:1 price:720.000 TL
# last_edit:5 Gün Önce area:90 m2 prop_floor:5. Kat building_age:22 Yaşında heating_type:Kombi building_floors:7 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type: building_status: usage_status: deed: dues: swap: student_single: facade: fuel_type:
# --------------------------------
# city:İstanbul district:Esenyurt neighborhood:Aşık Veysel prop_type:Daire rooms:3 living_room:1 price:465.000 TL
# last_edit:5 Gün Önce area:128 m2 prop_floor:4. Kat building_age:20 Yaşında heating_type:Merkezi building_floors:8 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues:180 TL swap:Hayır student_single:Evet facade:Doğu fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Adalar neighborhood:Nizam prop_type:Müstakil Ev rooms:3 living_room:1 price:1.190.000 TL
# last_edit:17 Gün Önce area:160 m2 prop_floor: building_age:50 Yaşında heating_type:Kombi building_floors: credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Ahşap building_status:İkinci El usage_status:Boş deed: dues: swap: student_single: facade: fuel_type:Elektrik
# --------------------------------
# city:İstanbul district:Üsküdar neighborhood:Kuzguncuk prop_type:Daire rooms:3 living_room:1 price:3.750.000 TL
# last_edit:21 Gün Önce area:140 m2 prop_floor:2. Kat building_age:31 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:2 building_type:Betonarme building_status:İkinci El usage_status:Ev Sahibi Oturuyor deed:Kat Mülkiyeti dues: swap:Hayır student_single:Evet facade:Güney fuel_type:Doğalgaz
# --------------------------------
# city:İstanbul district:Bakırköy neighborhood:Zuhuratbaba prop_type:Daire rooms:2 living_room:1 price:520.000 TL
# last_edit:18 Gün Önce area:90 m2 prop_floor:2. Kat building_age:35 Yaşında heating_type:Kombi building_floors:5 Katlı credit_availability:Uygun furniture_availability:Eşyalı Değil bathrooms:1 building_type:Betonarme building_status:İkinci El usage_status:Boş deed: dues: swap:Hayır student_single: facade: fuel_type:Doğalgaz
# --------------------------------

# %%
props_dict = {'city': [], 'district': [], 'neighborhood': [], 'prop_type': [], 'rooms': [], 'living_room': [], 'price':[],
              'last_edit': [], 'prop_type': [], 'area': [], 'prop_floor': [], 'building_age': [], 'heating_type': [],
              'building_floors': [], 'credit_availability': [], 'furniture_availability': [], 'bathrooms': [],
              'building_type': [], 'building_status': [], 'usage_status': [], 'deed': [], 'dues': [], 'swap': [],
              'student_single': [], 'facade': [], 'fuel_type': []}
for prop in objects_list:
    props_dict['city'].append(prop.base_info.city)
    props_dict['district'].append(prop.base_info.district)
    props_dict['neighborhood'].append(prop.base_info.neighborhood)
    props_dict['prop_type'].append(prop.base_info.prop_type)
    props_dict['rooms'].append(prop.base_info.rooms)
    props_dict['living_room'].append(prop.base_info.living_room)
    props_dict['price'].append(prop.base_info.price)
    
    props_dict['last_edit'].append(prop.last_edit)
    props_dict['area'].append(prop.area)
    props_dict['prop_floor'].append(prop.prop_floor)
    props_dict['building_age'].append(prop.building_age)
    props_dict['heating_type'].append(prop.heating_type)
    props_dict['building_floors'].append(prop.building_floors)
    props_dict['credit_availability'].append(prop.credit_availability)
    props_dict['furniture_availability'].append(prop.furniture_availability)
    props_dict['bathrooms'].append(prop.bathrooms)
    props_dict['building_type'].append(prop.building_type)
    props_dict['building_status'].append(prop.building_status)
    props_dict['usage_status'].append(prop.usage_status)
    props_dict['deed'].append(prop.deed)
    props_dict['dues'].append(prop.dues)
    props_dict['swap'].append(prop.swap)
    props_dict['student_single'].append(prop.student_single)
    props_dict['facade'].append(prop.facade)
    props_dict['fuel_type'].append(prop.fuel_type)

for key in props_dict.keys():
    print('size: {}'.format(len(props_dict[key])))
# Out:
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800
# size: 4800

# %%
dataframe = pd.DataFrame(props_dict)
dataframe.to_csv('./data/hurriyet7.csv',index=False)

# %%
dataframe = pd.read_csv('./data/hurriyet7.csv')
dataframe.head()
# Out:
#        city    district neighborhood    prop_type  rooms  living_room  \
# 0  İstanbul  Eyüpsultan  Akşemsettin        Daire      4            2
# 1  İstanbul     Silivri    Selimpaşa  Çiftlik Evi     15            2
# 2  İstanbul     Silivri      Ortaköy        Villa     12            1
# 3  İstanbul     Maltepe   Aydınevler        Daire      2            1
# 4  İstanbul       Fatih   Ayvansaray  Müstakil Ev      2            2
#
#            price    last_edit    area  prop_floor  ... bathrooms  \
# 0     670.000 TL   9 Gün Önce  210 m2      4. Kat  ...         2
# 1  17.500.000 TL   9 Gün Önce  850 m2  Villa Katı  ...         5
# 2   4.000.000 TL   7 Gün Önce  500 m2  Villa Katı  ...         2
# 3     390.000 TL   7 Gün Önce   90 m2      2. Kat  ...         1
# 4     320.000 TL  34 Gün Önce  135 m2         NaN  ...         1
#
#   building_type building_status        usage_status           deed    dues  \
# 0     Betonarme       İkinci El  Ev Sahibi Oturuyor  Kat Mülkiyeti   35 TL
# 1     Betonarme       İkinci El  Ev Sahibi Oturuyor           Arsa     NaN
# 2           NaN             NaN                 NaN            NaN     NaN
# 3     Betonarme           Sıfır                 Boş  Kat Mülkiyeti  120 TL
# 4           NaN             NaN                 NaN            NaN     NaN
#
#     swap student_single facade fuel_type
# 0  Hayır            NaN   Doğu  Doğalgaz
# 1    NaN            NaN    NaN  Doğalgaz
# 2    NaN            NaN    NaN       NaN
# 3  Hayır           Evet    NaN  Doğalgaz
# 4    NaN            NaN    NaN       NaN
#
# [5 rows x 25 columns]
