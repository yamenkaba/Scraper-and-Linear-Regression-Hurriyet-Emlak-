# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 629)
pd.set_option('display.max_columns', 30)

# %%
df1 = pd.read_csv('./data/hurriyet1.csv')
df2 = pd.read_csv('./data/hurriyet2.csv')
df3 = pd.read_csv('./data/hurriyet3.csv')
df4 = pd.read_csv('./data/hurriyet4.csv')
df5 = pd.read_csv('./data/hurriyet5.csv')
df6 = pd.read_csv('./data/hurriyet6.csv')
df_combined = pd.concat([df1,df2,df3,df4,df5,df6])
df_combined.drop_duplicates(inplace=True)
df_combined.reset_index(drop=True,inplace=True)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25119 entries, 0 to 25118
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    25119 non-null  object
#  1   district                25119 non-null  object
#  2   neighborhood            25119 non-null  object
#  3   prop_type               25119 non-null  object
#  4   rooms                   25119 non-null  int64
#  5   living_room             25119 non-null  int64
#  6   price                   25119 non-null  object
#  7   last_edit               25119 non-null  object
#  8   area                    25119 non-null  object
#  9   prop_floor              23849 non-null  object
#  10  building_age            25119 non-null  object
#  11  heating_type            25119 non-null  object
#  12  building_floors         23538 non-null  object
#  13  credit_availability     25117 non-null  object
#  14  furniture_availability  25119 non-null  object
#  15  bathrooms               25117 non-null  float64
#  16  building_type           21701 non-null  object
#  17  building_status         21983 non-null  object
#  18  usage_status            22387 non-null  object
#  19  deed                    19412 non-null  object
#  20  dues                    9719 non-null   object
#  21  swap                    17715 non-null  object
#  22  student_single          13358 non-null  object
#  23  facade                  18684 non-null  object
#  24  fuel_type               22486 non-null  object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 4.8+ MB

# %%
df_combined.head()
# Out:
#        city    district        neighborhood prop_type  rooms  living_room  \
# 0  İstanbul       Şişli               Fulya     Daire      3            1
# 1  İstanbul    Beşiktaş          Gayrettepe     Daire      3            1
# 2  İstanbul    Ümraniye          Yamanevler     Daire      3            1
# 3  İstanbul  Eyüpsultan      Göktürk Merkez     Villa      6            1
# 4  İstanbul     Avcılar  Mustafa Kemal Paşa     Daire      4            1
#
#            price last_edit    area  prop_floor building_age  \
# 0     980.000 TL     Bugün  140 m2      7. Kat   30 Yaşında
# 1     900.000 TL     Bugün  110 m2      8. Kat   30 Yaşında
# 2   1.890.000 TL     Bugün  178 m2     10. Kat   Sıfır Bina
# 3  12.500.000 TL     Bugün  500 m2  Villa Katı   10 Yaşında
# 4     329.000 TL     Bugün  155 m2      2. Kat   Sıfır Bina
#
#           heating_type building_floors credit_availability  \
# 0                Kombi         8 Katlı               Uygun
# 1              Merkezi         9 Katlı               Uygun
# 2  Merkezi (Pay Ölçer)        29 Katlı               Uygun
# 3                Kombi         4 Katlı               Uygun
# 4                Kombi         5 Katlı               Uygun
#
#   furniture_availability  bathrooms building_type building_status  \
# 0           Eşyalı Değil        2.0     Betonarme       İkinci El
# 1           Eşyalı Değil        1.0     Betonarme       İkinci El
# 2           Eşyalı Değil        2.0     Betonarme           Sıfır
# 3           Eşyalı Değil        4.0     Betonarme       İkinci El
# 4           Eşyalı Değil        1.0     Betonarme           Sıfır
#
#          usage_status           deed      dues   swap student_single  facade  \
# 0                 Boş  Kat Mülkiyeti    200 TL  Hayır           Evet  Güney,
# 1                 Boş  Kat Mülkiyeti    450 TL  Hayır           Evet  Kuzey,
# 2  Ev Sahibi Oturuyor  Kat Mülkiyeti    622 TL  Hayır           Evet  Güney,
# 3  Ev Sahibi Oturuyor  Kat Mülkiyeti  1.800 TL  Hayır           Evet  Güney,
# 4                 Boş  Kat Mülkiyeti       NaN   Evet           Evet   Güney
#
#   fuel_type
# 0  Doğalgaz
# 1  Doğalgaz
# 2  Doğalgaz
# 3  Doğalgaz
# 4  Doğalgaz

# %%
df_combined['city'].value_counts()
# Out:
# İstanbul    25119
# Name: city, dtype: int64

# %%
df_combined['district'].value_counts()
# Out:
# Kadıköy          3498
# Maltepe          1562
# Beylikdüzü       1479
# Sarıyer          1466
# Beşiktaş         1460
# Şişli            1445
# Bahçelievler     1316
# Bakırköy         1261
# Üsküdar          1131
# Kağıthane        1045
# Fatih             848
# Esenyurt          806
# Eyüpsultan        772
# Küçükçekmece      549
# Büyükçekmece      531
# Beyoğlu           525
# Avcılar           382
# Güngören          370
# Kartal            368
# Ataşehir          366
# Başakşehir        340
# Beykoz            331
# Çekmeköy          326
# Ümraniye          321
# Gaziosmanpaşa     291
# Adalar            265
# Sancaktepe        258
# Zeytinburnu       252
# Pendik            242
# Silivri           239
# Bağcılar          196
# Tuzla             191
# Bayrampaşa        165
# Şile              139
# Esenler           124
# Sultangazi         86
# Arnavutköy         82
# Sultanbeyli        55
# Çatalca            36
# Name: district, dtype: int64

# %%
df_combined['neighborhood'].value_counts()
# Out:
# Cumhuriyet                   908
# Suadiye                      751
# Caddebostan                  492
# Fenerbahçe                   427
# Siyavuşpaşa                  410
# Merkez                       404
# Göztepe                      400
# Altıntepe                    359
# Şenlikköy                    328
# Bahçelievler                 325
# Adnan Kahveci                323
# Erenköy                      312
# Maslak                       299
# Göktürk Merkez               288
# İdealtepe                    284
# Yeşilköy                     277
# Atatürk                      258
# Bostancı                     249
# Küçükyalı                    243
# Zekeriyaköy                  235
# Cihangir                     231
# Aydınevler                   204
# Fatih                        204
# Feneryolu                    178
# Kartaltepe                   175
# 19 Mayıs                     172
# Maden                        165
# Soğanlı                      160
# Bahçeşehir 2. Kısım          155
# Mecidiyeköy                  155
# Tarabya                      154
# Kozyatağı                    151
# Teşvikiye                    151
# Yakuplu                      145
# Şehremini                    142
# Fulya                        141
# Valide-i Atik                140
# Levent                       140
# Ulus                         140
# Zafer                        138
# Dikilitaş                    134
# Mimar Sinan                  132
# Etiler                       130
# Yenibosna Merkez             124
# Yeşilyurt                    122
# Seyyid Ömer                  121
# Hürriyet                     120
# Kavaklı                      119
# Beylikdüzü OSB               117
# Esentepe                     117
# İstinye                      114
# Çeliktepe                    113
# Abdurrahman Nafiz Gürman     113
# Zuhuratbaba                  108
# Ortabayır                    108
# Nizam                        108
# Eskişehir                    108
# Cennet                       105
# Levazım                      103
# Caferağa                     103
# Atakent                      102
# Feyzullah                    101
# Acarlar                       99
# Koca Mustafapaşa              98
# Yeniköy                       97
# Kocasinan Merkez              96
# Gülbahar                      95
# İnönü                         94
# Bozkurt                       93
# Çınar                         91
# Cevizli                       90
# Bağlarbaşı                    90
# Bebek                         89
# Yeni Mahalle                  81
# Barbaros                      81
# Zeynep Kamil                  81
# Feriköy                       80
# Sultan Selim                  80
# Merdivenköy                   79
# Gürpınar                      79
# Paşa                          78
# Ekşioğlu                      78
# Çırçır                        77
# İcadiye                       75
# Ayazağa                       74
# Mustafa Kemal Paşa            73
# Karadolap                     72
# Çengelköy                     71
# Talatpaşa                     71
# Bulgurlu                      70
# Arnavutköy                    70
# Bahçeşehir 1. Kısım           70
# Barış                         69
# Silivrikapı                   69
# Uskumruköy                    68
# Gayrettepe                    68
# Kavacık                       68
# Çağlayan                      68
# İçerenköy                     68
# Yıldız                        67
# Sultantepe                    66
# Güzelyurt                     66
# Murat Reis                    65
# Şirinevler                    65
# Güzeltepe                     64
# Yenişehir                     64
# Akat                          64
# Telsizler                     64
# Ortaköy                       63
# Salacak                       60
# Yayla                         59
# Vişnezade                     59
# Türkali                       58
# Nisbetiye                     57
# Ambarlı                       57
# Gültepe                       56
# Sahrayı Cedit                 56
# Mareşal Çakmak                55
# Altayçeşme                    55
# Büyükdere                     55
# Aziz Mahmut Hüdayi            53
# Selami Ali                    53
# Mimaroba                      53
# Yalı                          52
# Gürsel                        52
# Yeni                          51
# Emniyet Evleri                51
# Harmantepe                    51
# Çavuş                         50
# Denizköşkler                  49
# Ataköy 2-5-6. Kısım           49
# Karadeniz                     48
# Kayabaşı                      48
# Firuzağa                      48
# Pınartepe                     48
# Seyrantepe                    48
# Halide Edip Adıvar            48
# Zümrütevler                   47
# Yeşilova                      46
# Yunus Emre                    46
# Sakızağacı                    44
# İstasyon                      44
# Dereağzı                      44
# Marmara                       44
# Emirgan                       44
# Haznedar                      44
# Selimpaşa                     43
# Acıbadem                      43
# Ataköy 7-8-9-10. Kısım        42
# Gümüşsuyu                     42
# Altıntepsi                    42
# Mehterçeşme                   42
# Mecidiye                      42
# Yahya Kemal                   42
# Meşrutiyet                    42
# Harbiye                       41
# Postane                       41
# Şirintepe                     40
# Atalar                        40
# İstiklal                      39
# Osmanağa                      39
# Mehmet Akif                   39
# Kazım Karabekir               39
# Balat                         39
# Mevlana                       39
# Abbasağa                      39
# Fevzi Çakmak                  38
# Barbaros Hayrettin Paşa       38
# Yeşilkent                     38
# Piri Reis                     37
# Haseki Sultan                 37
# Halkalı Merkez                37
# Aydınlar                      37
# Kumköy                        37
# Çamlık                        37
# Emek                          36
# Pınar                         36
# Mithatpaşa                    36
# Hamidiye                      36
# Yenidoğan                     35
# Büyükşehir                    35
# Kılıçali Paşa                 35
# Sümer                         35
# Akşemsettin                   35
# Kordonboyu                    35
# Yenimahalle                   35
# Molla Gürani                  35
# Cerrahpaşa                    34
# Sahil                         34
# Rasimpaşa                     34
# Küçükbakkalköy                34
# Muradiye                      34
# Doğu                          33
# Nuripaşa                      33
# Selimiye                      33
# Petroliş                      33
# Ahmediye                      33
# İslambey                      33
# Mevlanakapı                   32
# Kayışdağı                     32
# Duatepe                       32
# Örnek                         32
# Balibey                       32
# Karlıktepe                    32
# Zühtüpaşa                     32
# Esenkent                      32
# Uğur Mumcu                    31
# Orhantepe                     31
# Namık Kemal                   31
# Huzur                         31
# Basınköy                      31
# Ayvansaray                    30
# Kuzguncuk                     30
# Yeşilce                       30
# Emniyettepe                   29
# Güven                         29
# Kuruçeşme                     29
# Osmaniye                      29
# Cevizlik                      29
# Konaklar                      29
# Hasanpaşa                     28
# Sümbül Efendi                 28
# Koza                          28
# Kandilli                      27
# Yıldırım                      27
# Mehmet Nesih Özmen            27
# Heybeliada                    27
# Aydınlı                       27
# Ardıçlı                       27
# Mehmet Akif Ersoy             27
# Kuştepe                       26
# Güneştepe                     26
# Burgazada                     26
# Demirciköy                    26
# Ziya Gökalp                   26
# Osmangazi                     25
# Yedikule                      25
# Güzelce                       25
# Muratpaşa                     25
# Ferahevler                    25
# Batı                          24
# Maltepe                       24
# Abdurrahmangazi               24
# Anadolu Hisarı                24
# Nurtepe                       23
# Tozkoparan                    23
# Çobançeşme                    23
# Sinanoba                      23
# Necip Fazıl                   22
# Zeytinlik                     22
# Yeşiltepe                     22
# Fetih                         22
# Pürtelaş Hasan Efendi         22
# Evliya Çelebi                 22
# Mahmutbey                     22
# Seyitnizam                    22
# Ekinoba                       21
# Ferah                         21
# Fikirtepe                     21
# Akıncılar                     21
# Başakşehir                    21
# Armağanevler                  21
# Meclis                        21
# Beylerbeyi                    21
# Kazlıçeşme                    21
# Tatlısu                       21
# Cihannüma                     21
# Fındıklı                      21
# Rumeli Hisarı                 20
# Merkezefendi                  20
# Tuna                          20
# Üniversite                    20
# Kanlıca                       20
# Ünalan                        20
# Topkapı                       20
# İskenderpaşa                  20
# Adil                          19
# Piri Mehmet Paşa              19
# Esenyalı                      19
# Kaynarca                      18
# Darüşşafaka                   18
# Anadolu                       18
# Semizkumlar                   18
# 15 Temmuz                     18
# Kuloğlu                       17
# Güneşli                       17
# Silahtarağa                   17
# Site                          17
# Esatpaşa                      17
# Battalgazi                    17
# Gümüşyaka                     17
# Koşuyolu                      17
# Riva                          17
# Kınalıada                     17
# Sakarya                       16
# Tahtakale                     16
# Yıldıztabya                   16
# Hacıahmet                     16
# Veliefendi                    16
# Eyüp Sultan                   16
# Tomtom                        16
# Beştelsiz                     16
# Akevler                       16
# Karlıtepe                     16
# Tantavi                       16
# Orta                          15
# Sultançiftliği                15
# Yeşilpınar                    15
# Söğütlü Çeşme                 15
# Şemsipaşa                     15
# Soğanlık Yeni                 15
# Alemdağ                       15
# Celaliye                      14
# Esenevler                     14
# Yavuz Sultan Selim            14
# Telsiz                        14
# Gümüşpala                     14
# Bağlarçeşme                   14
# Yenigün                       14
# Cebeci                        14
# İncirtepe                     14
# Topselvi                      14
# Aksaray                       14
# Selahaddin Eyyubi             13
# Türkoba                       13
# Birlik                        13
# Taşdelen                      13
# Derviş Ali                    13
# Kirazlı                       13
# Bağlar                        13
# Nişancı                       13
# Sinanpaşa                     13
# Saadetdere                    13
# Ergenekon                     12
# Eğitim                        12
# Gökalp                        12
# Kumburgaz                     12
# Madenler                      12
# Aydıntepe                     12
# Balıkyolu                     12
# Ahmet Yesevi                  12
# Örnektepe                     12
# Alibey                        12
# Sururi Mehmet Efendi          12
# Alibeyköy                     12
# Sarıgöl                       12
# Kanarya                       12
# Şerifali                      12
# Yavuz Selim                   11
# Gazi                          11
# Rami Cuma                     11
# Karayolları                   11
# Çatalmeşe                     11
# Balmumcu                      11
# Sütlüce                       11
# Küçüksu                       11
# Sancaktepe                    11
# Kireçburnu                    11
# Soğukpınar                    11
# Çınardere                     11
# Çırpıcı                       11
# Kumbaba                       11
# Ataköy 3-4-11. Kısım          11
# Çubuklu                       11
# Dumlupınar                    11
# Kurtköy                       11
# Ataköy 1. Kısım               10
# Kısıklı                       10
# Güngören                      10
# Orhan Gazi                    10
# Dizdariye                     10
# Kültür                        10
# Ali Kuşçu                     10
# Atikali                       10
# Halil Rıfat Paşa              10
# Halaskargazi                  10
# Ortamahalle                   10
# Gökevler                      10
# Düğmeciler                    10
# Bahçeköy Yeni                  9
# Yamanevler                     9
# Yahya Kahya                    9
# Yenikent                       9
# Çakmak                         9
# Ömer Avni                      9
# Hadımköy                       9
# Nine Hatun                     9
# Alkent 2000                    9
# Altınşehir                     9
# Velibaba                       9
# Esenşehir                      9
# Fener                          9
# Soğuksu                        9
# Kalyoncu Kulluğu               9
# Katip Mustafa Çelebi           9
# Çatma Mescit                   8
# Baltalimanı                    8
# Bahçeköy Merkez                8
# Aşıkveysel                     8
# Başıbüyük                      8
# Süleymaniye                    8
# Merve                          8
# Karaağaç                       8
# Girne                          8
# Murat Çeşme                    8
# Hırka-i Şerif                  8
# Başak                          8
# Şifa                           8
# Altunizade                     8
# Sarıgazi                       8
# Kamiloba                       8
# Mavigöl                        8
# Üçevler                        8
# Yukarı Dudullu                 8
# Yakacık Yeni                   7
# Veysel Karani                  7
# Küçük Piyale                   7
# Barbaros Hayrettinpaşa         7
# Ahmetli                        7
# Yalıköy                        7
# Cibali                         7
# Bolluca                        7
# Reşadiye                       7
# Kaptanpaşa                     7
# Karagümrük                     7
# Halıcıoğlu                     7
# Kirazlıdere                    7
# Cami                           7
# Kocatepe                       7
# Kemalpaşa                      7
# Menderes                       7
# Asmalı Mescit                  6
# Harmandere                     6
# Tepeören                       6
# Yıldıztepe                     6
# İsmetpaşa                      6
# Güzelyalı                      6
# Burhaniye                      6
# Paşabahçe                      6
# Gümüşpınar                     6
# Göçbeyli                       6
# Hacımimi                       6
# Mahmutşevketpaşa               6
# Kemal Türkler                  6
# Adem Yavuz                     6
# Vatan                          6
# Ferhatpaşa                     6
# Zübeyde Hanım                  6
# Küçük Çamlıca                  6
# Rami Yeni                      6
# Cevatpaşa                      6
# Balaban                        6
# Yeni Çamlıca                   6
# Sultan Murat                   6
# Kamer Hatun                    6
# İzzet Paşa                     6
# Kadımehmet Efendi              5
# Demirkapı                      5
# Müeyyetzade                    5
# Kulaksız                       5
# Mimar Sinan Merkez             5
# Fatih Sultan Mehmet            5
# İkitelli OSB                   5
# Zeyrek                         5
# Aşık Veysel                    5
# Bereketzade                    5
# Şahkulu                        5
# Ömerli                         5
# Göksu                          5
# Akpınar                        5
# Pazariçi                       5
# Yunus                          5
# İncirköy                       5
# Güvercintepe                   5
# Parseller                      5
# Safa                           5
# Sanayi                         4
# Arnavutköy Merkez              4
# Gençosman                      4
# Kabakça                        4
# Yarımburgaz                    4
# Çengeldere                     4
# Çiftlik                        4
# Ovayenice                      4
# Necip Fazıl Kısakürek          4
# Alipaşa                        4
# Rumeli Kavağı                  4
# Yeni Sahra                     4
# Tevfik Bey                     4
# Poligon                        4
# Yavuztürk                      4
# Elmalıkent                     4
# Terazidere                     4
# Şuayipli                       4
# Yakacık Çarşı                  4
# Piri Paşa                      4
# Karlıbayır                     3
# Boğazköy İstiklal              3
# Çamlıbahçe                     3
# Nişantepe                      3
# Reşitpaşa                      3
# Firuzköy                       3
# Nişanca                        3
# Havaalanı                      3
# Çamçeşme                       3
# Haraççı                        3
# Çakmaklı                       3
# Şehit Muhtar                   3
# Görele                         3
# İmrenli                        3
# Saray                          3
# Eski Habipler                  3
# Keçeci Piri                    3
# Çakıl                          3
# Sahilköy                       3
# Akşemseddin                    3
# Camiikebir                     3
# Turgut Özal                    3
# Sülüntepe                      3
# Beşyol                         3
# Esenler                        3
# Sultaniye                      3
# Ertuğrul Gazi                  3
# Şehitler                       3
# Akçaburgaz                     3
# Hastane                        3
# Örnekköy                       3
# Sapan Bağları                  3
# Subaşı                         3
# Tepeüstü                       3
# İmrendere                      3
# Hüseyinağa                     3
# Baklacı                        3
# İzzettin                       2
# Dağyenice                      2
# Taşoluk                        2
# Zerzavatçı                     2
# Şeyhli                         2
# Kemer                          2
# Büyük Sinekli                  2
# Molla Hüsrev                   2
# Kuleli                         2
# Ağaçlı                         2
# Aşağı Dudullu                  2
# İçmeler                        2
# Yayalar                        2
# Kabakoz                        2
# Çavuşoğlu                      2
# Bostan                         2
# Elmalı                         2
# Yukarı                         2
# Polonezköy                     2
# Hoca Paşa                      2
# Orhangazi                      2
# Kestanelik                     2
# İnkılap                        2
# Davutpaşa                      2
# Topçular                       2
# Rumelifeneri                   2
# Tayakadın                      2
# Kızılca                        2
# Güllü Bağlar                   2
# Hacı Kasım                     2
# 50. Yıl                        2
# Kadıköy                        2
# Kocataş                        2
# Kavakpınar                     2
# Kılıçlı                        2
# Akçakese                       2
# Ptt Evleri                     2
# Gökçeali                       2
# Arap Cami                      2
# Seymen                         2
# Saraç İshak                    1
# Habibler                       1
# Bekirli                        1
# Küçük Sinekli                  1
# Sultan Ahmet                   1
# 100. Yıl                       1
# Gülsuyu                        1
# 75. Yıl                        1
# Bülbül                         1
# Çelebi                         1
# Oruçreis                       1
# Değirmençayırı                 1
# Mahmut Şevket Paşa             1
# Çiğdem                         1
# Kaptan Paşa                    1
# Çukur                          1
# Ortaçeşme                      1
# Yeşilbağlar                    1
# Çamlıtepe                      1
# Molla Fenari                   1
# Karakiraz                      1
# Mareşal Fevzi Çakmak           1
# Kurfallı                       1
# Yeşilbayır                     1
# Oklalı                         1
# Boyalık                        1
# Malkoçoğlu                     1
# Karaburun                      1
# Şehsuvar Bey                   1
# Sırapınar                      1
# Hüseyinli                      1
# Muhsine Hatun                  1
# Kazım Karabekir Paşa           1
# Bahçeköy Kemer                 1
# Elbasan                        1
# Çeltik                         1
# Paşamandıra                    1
# Bedrettin                      1
# Defterdar                      1
# Tokatköy                       1
# Yazlık                         1
# Akören                         1
# Ihlamurkuyu                    1
# Küçükçekmece İkitelli OSB      1
# Karacaköy                      1
# Cemil Meriç                    1
# Mimar Hayrettin                1
# Gümüşdere                      1
# Karamandere                    1
# Büyük Çavuşlu                  1
# Göçe                           1
# Hilal                          1
# Kömürlük                       1
# İsmet Paşa                     1
# Kalfa                          1
# Binbirdirek                    1
# Name: neighborhood, dtype: int64

# %%
# df_combined = df_combined[df_combined.prop_type=='Daire']

# %%
df_combined['prop_type'].value_counts()
# Out:
# Daire           21698
# Villa            1354
# Residence        1067
# Bina              414
# Müstakil Ev       331
# Köşk               62
# Yalı Dairesi       56
# Yalı               51
# Çiftlik Evi        41
# Yazlık             27
# Köy Evi             9
# Loft Daire          6
# Kooperatif          2
# Dağ Evi             1
# Name: prop_type, dtype: int64

# %%
# df_combined = df_combined[df_combined.rooms <= 5]

# %%
df_combined['rooms'].value_counts()
# Out:
# 2      8708
# 3      7939
# 4      3418
# 1      2180
# 5      1602
# 6       652
# 7       233
# 8       140
# 9        64
# 10       48
# 12       33
# 15       17
# 16       11
# 14       11
# 20        8
# 21        8
# 31        6
# 11        6
# 30        5
# 18        4
# 40        3
# 22        3
# 51        2
# 32        2
# 17        2
# 125       2
# 140       2
# 26        2
# 25        2
# 135       1
# 13        1
# 27        1
# 36        1
# 41        1
# 295       1
# Name: rooms, dtype: int64

# %%
# df_combined = df_combined[(df_combined.living_room==1) | (df_combined.living_room==2)]

# %%
df_combined['living_room'].value_counts()
# Out:
# 1      21719
# 2       2901
# 3        203
# 0        107
# 4         91
# 5         29
# 8         13
# 7         13
# 6         12
# 10         5
# 11         4
# 9          4
# 150        3
# 20         2
# 135        2
# 120        2
# 105        2
# 32         2
# 15         2
# 12         1
# 18         1
# 25         1
# Name: living_room, dtype: int64

# %%
df_combined.loc[:,'price'] = df_combined.loc[:,'price'].str.split(' ').str[0]
df_combined.loc[:,'price'] = df_combined.loc[:,'price'].str.replace('.','')
df_combined.loc[:,'price'] = df_combined.loc[:,'price'].str.replace(',','')
df_combined['price'] = df_combined['price'].astype('int64')

# %%
df_combined['price']
# Out:
# 0          980000
# 1          900000
# 2         1890000
# 3        12500000
# 4          329000
#            ...
# 25114      460000
# 25115     1500000
# 25116     3850000
# 25117      235000
# 25118      535000
# Name: price, Length: 25119, dtype: int64

# %%
mapper_last_edit = {
    'Bugün': '0 Gun',
    'Dün': '1 Gun'
}

df_combined['last_edit'] = df_combined['last_edit'].map(mapper_last_edit).fillna(df_combined['last_edit'])
df_combined.loc[:,'last_edit'] = df_combined.loc[:,'last_edit'].str.split(' ').str[0]
df_combined['last_edit'] = df_combined['last_edit'].astype('int64')
df_combined['last_edit'] = df_combined['last_edit']

# %%
df_combined['last_edit'].value_counts()
# Out:
# 4      2367
# 3      2116
# 5      1935
# 0      1607
# 6      1217
# 9      1156
# 1      1062
# 2      1040
# 10      980
# 8       831
# 11      733
# 7       729
# 13      713
# 12      670
# 19      574
# 16      557
# 17      556
# 18      515
# 15      495
# 20      485
# 23      456
# 14      450
# 25      411
# 24      370
# 26      365
# 22      347
# 27      333
# 21      308
# 28      276
# 30      248
# 29      222
# 31      137
# 32       86
# 33       69
# 37       54
# 36       46
# 35       46
# 38       40
# 41       38
# 34       37
# 39       35
# 42       34
# 40       33
# 44       30
# 45       28
# 43       26
# 46       25
# 48       21
# 54       17
# 58       17
# 55       16
# 59       15
# 52       15
# 49       15
# 47       13
# 53       13
# 56       13
# 51       12
# 50       12
# 57       11
# 60        8
# 68        3
# 88        3
# 62        3
# 70        3
# 82        3
# 64        2
# 80        1
# 118       1
# 71        1
# 94        1
# 142       1
# 61        1
# 119       1
# 65        1
# 81        1
# 97        1
# 73        1
# 92        1
# 98        1
# 72        1
# 99        1
# 159       1
# Name: last_edit, dtype: int64

# %%
df_combined['area'] = df_combined.loc[:,'area'].str.split(' ').str[0]
df_combined['area'] = df_combined['area'].astype('float64')

# %%
df_combined['area']
# Out:
# 0        140.0
# 1        110.0
# 2        178.0
# 3        500.0
# 4        155.0
#          ...
# 25114     95.0
# 25115     85.0
# 25116    590.0
# 25117    110.0
# 25118    130.0
# Name: area, Length: 25119, dtype: float64

# %%
df_combined.loc[:,'prop_floor'] = df_combined.loc[:,'prop_floor'].str.split(' ').str[0]

asma_index = df_combined[df_combined['prop_floor'] == 'Asma'].index
villa_index = df_combined[df_combined['prop_floor'] == 'Villa'].index
bodrum_index = df_combined[df_combined['prop_floor'] == 'Bodrum'].index
teras_index = df_combined[df_combined['prop_floor'] == 'Teras'].index
zemin_index = df_combined[df_combined['prop_floor'] == 'Zemin'].index
yari_index = df_combined[df_combined['prop_floor'] == 'Yarı'].index
cat_index = df_combined[df_combined['prop_floor'] == 'Çatı'].index
ara_index = df_combined[df_combined['prop_floor'] == 'Ara'].index
en_index = df_combined[df_combined['prop_floor'] == 'En'].index
kot_index = df_combined[df_combined['prop_floor'] == 'Kot'].index

df_combined.drop(asma_index , inplace=True)
df_combined.drop(villa_index , inplace=True)
df_combined.drop(bodrum_index , inplace=True)
df_combined.drop(teras_index , inplace=True)
df_combined.drop(zemin_index , inplace=True)
df_combined.drop(yari_index , inplace=True)
df_combined.drop(cat_index , inplace=True)
df_combined.drop(ara_index , inplace=True)
df_combined.drop(en_index , inplace=True)
df_combined.drop(kot_index , inplace=True)

# %%
df_combined = df_combined.dropna(subset=['prop_floor'])

mapper_prop_floor = {
    'Bahçe': '0.',
    'Giriş': '0.',
    'Yüksek': '1.',
}

df_combined['prop_floor'] = df_combined['prop_floor'].map(mapper_prop_floor).fillna(df_combined['prop_floor'])
df_combined.loc[:,'prop_floor'] = df_combined.loc[:,'prop_floor'].str.split('.').str[0]
df_combined['prop_floor'] = df_combined['prop_floor'].astype('int64')
df_combined['prop_floor'] = df_combined['prop_floor'] + 1

# %%
df_combined['prop_floor'].value_counts()
# Out:
# 2     3905
# 4     2979
# 3     2815
# 1     2752
# 5     2676
# 6     1522
# 7      709
# 8      573
# 9      515
# 11     505
# 10     488
# 12     334
# 13     289
# 22     276
# 14     215
# 15     183
# 16     115
# 18      61
# 17      57
# 19      38
# 20      33
# 21      32
# Name: prop_floor, dtype: int64

# %%
df_combined.loc[:,'building_age'] = df_combined.loc[:,'building_age'].str.split(' ').str[0]

mapper_building_age = {
    'Sıfır': '0'
}

df_combined['building_age'] = df_combined['building_age'].map(mapper_building_age).fillna(df_combined['building_age'])
df_combined['building_age'] = df_combined['building_age'].astype('int64')

# %%
df_combined['building_age'].value_counts()
# Out:
# 0      5699
# 30     1311
# 25     1097
# 4      1060
# 2      1030
# 1      1030
# 3       917
# 5       772
# 20      738
# 10      720
# 35      684
# 8       536
# 40      483
# 15      435
# 7       430
# 6       402
# 12      278
# 28      263
# 9       263
# 26      220
# 22      174
# 27      162
# 18      156
# 16      152
# 21      149
# 13      146
# 29      143
# 11      137
# 32      126
# 23      124
# 19      121
# 31      119
# 45      115
# 14      111
# 50      109
# 17       96
# 24       90
# 38       61
# 33       55
# 34       47
# 36       40
# 37       36
# 60       33
# 42       22
# 100      21
# 80       20
# 39       19
# 43       11
# 46       10
# 55        9
# 90        8
# 44        8
# 41        8
# 48        7
# 70        6
# 65        5
# 49        5
# 95        4
# 52        4
# 130       3
# 110       3
# 75        3
# 74        2
# 120       2
# 150       2
# 51        2
# 53        2
# 85        1
# 98        1
# 47        1
# 67        1
# 250       1
# 96        1
# 128       1
# 58        1
# 201       1
# 69        1
# 87        1
# 99        1
# 79        1
# 86        1
# 117       1
# 71        1
# Name: building_age, dtype: int64

# %%
# mapper_heating_type = {
#     'Merkezi (Pay Ölçer)': 'Merkezi'
# }

# df_combined['heating_type'] = df_combined['heating_type'].map(mapper_heating_type).fillna(df_combined['heating_type'])

# %%
heating_type_oreder = df_combined['heating_type'].value_counts()
heating_type_oreder
# Out:
# Kombi                  15127
# Merkezi (Pay Ölçer)     3317
# Merkezi                 2156
# Soba                     139
# Klima                     97
# Belirtilmemiş             81
# Kat Kaloriferi            73
# Isıtma Yok                66
# Jeotermal Isıtma          12
# Güneş Enerjisi             4
# Name: heating_type, dtype: int64

# %%
mark = list(heating_type_oreder[heating_type_oreder < 111].index)
df_combined["heating_type"] = df_combined["heating_type"].replace(mark,"Diger")

# %%
mapper_heating_type = {
    'Soba': 1,
    'Diger': 2,
    'Kombi': 3,
    'Merkezi': 4,
    'Merkezi (Pay Ölçer)': 5
}

df_combined['heating_type'] = df_combined['heating_type'].map(mapper_heating_type)
df_combined['heating_type'] = df_combined['heating_type'].astype('int64')

# %%
df_combined.loc[:,'building_floors'] = df_combined.loc[:,'building_floors'].str.split(' ').str[0]
df_combined = df_combined.dropna(subset=['building_floors'])

# %%
df_combined['building_floors'] = df_combined['building_floors'].astype('int64')
df_combined['building_floors'].value_counts()
# Out:
# 4      5539
# 5      4883
# 3      1779
# 6      1465
# 9       751
# 7       731
# 10      729
# 8       679
# 12      570
# 14      557
# 11      499
# 13      431
# 15      365
# 2       258
# 17      167
# 16      156
# 20      140
# 18      130
# 30       81
# 32       81
# 22       78
# 33       77
# 19       77
# 1        59
# 25       58
# 52       43
# 24       43
# 42       42
# 23       41
# 21       40
# 40       38
# 29       28
# 27       23
# 31       22
# 35       21
# 44       20
# 45       19
# 34       18
# 36       17
# 28       17
# 26       14
# 55       13
# 37        8
# 48        8
# 39        6
# 56        5
# 54        4
# 50        4
# 38        4
# 51        4
# 41        4
# 46        2
# 75        1
# 65        1
# 57        1
# 112       1
# 190       1
# 47        1
# Name: building_floors, dtype: int64

# %%
df_combined['credit_availability'].fillna('Bilinmiyor',inplace=True)
# credit_availability_bilinmiyor_index = df_combined[df_combined['credit_availability'] == 'Bilinmiyor'].index
# df_combined.drop(credit_availability_bilinmiyor_index, inplace=True)

# %%
df_combined['credit_availability'].value_counts()
# Out:
# Uygun          19736
# Uygun değil      985
# Bilinmiyor       133
# Name: credit_availability, dtype: int64

# %%
df_combined['furniture_availability'].value_counts()
# Out:
# Eşyalı Değil    20254
# Eşyalı            600
# Name: furniture_availability, dtype: int64

# %%
df_combined['bathrooms'].fillna(1,inplace=True)
df_combined['bathrooms'] = df_combined['bathrooms'].astype('int64')
# df_combined = df_combined[(df_combined.bathrooms==1) | (df_combined.bathrooms==2) | (df_combined.bathrooms==3)]

# %%
df_combined['bathrooms'].value_counts()
# Out:
# 1     11500
# 2      7003
# 3      1593
# 4       528
# 5       125
# 6        45
# 7        13
# 8         7
# 20        5
# 10        5
# 9         5
# 15        3
# 14        3
# 24        3
# 11        3
# 13        3
# 16        3
# 21        2
# 23        1
# 25        1
# 27        1
# 12        1
# 29        1
# Name: bathrooms, dtype: int64

# %%
df_combined['building_type'].fillna('Diğer',inplace=True)
# df_combined = df_combined[df_combined.building_type=='Betonarme']

# %%
df_combined['building_type'].value_counts()
# Out:
# Betonarme    18294
# Diğer         2183
# Çelik          149
# Kagir          129
# Yığma           44
# Ahşap           38
# Taş Bina        14
# Kütük            2
# Prefabrik        1
# Name: building_type, dtype: int64

# %%
df_combined['building_status'].fillna('İkinci El',inplace=True)

# %%
df_combined['building_status'].value_counts()
# Out:
# İkinci El           13810
# Sıfır                6973
# Yapım Aşamasında       71
# Name: building_status, dtype: int64

# %%
mapper_building_status = {
    'Yapım Aşamasında': 1,
    'İkinci El': 2,
    'Sıfır': 3
}

df_combined['building_status'] = df_combined['building_status'].map(mapper_building_status)
df_combined['building_status'] = df_combined['building_status'].astype('int64')

# %%
df_combined['usage_status'].fillna('Diğer',inplace=True)

mapper_usage_status = {
    'Belirtilmemiş': 'Diğer'
}

df_combined['usage_status'] = df_combined['usage_status'].map(mapper_usage_status).fillna(df_combined['usage_status'])

# %%
df_combined['usage_status'].value_counts()
# Out:
# Boş                   10737
# Kiracı Oturuyor        4199
# Ev Sahibi Oturuyor     4027
# Diğer                  1891
# Name: usage_status, dtype: int64

# %%
df_combined['deed'].fillna('Diğer',inplace=True)
deed_index = df_combined[df_combined['deed'] == 'Arsa'].index
df_combined.drop(deed_index , inplace=True)

# %%
df_combined['deed'].value_counts()
# Out:
# Kat Mülkiyeti    13324
# Diğer             4096
# Kat İrtifakı      2812
# Name: deed, dtype: int64

# %%
df_combined.drop('dues',axis=1,inplace=True)

# %%
df_combined['swap'].fillna('Diğer',inplace=True)

# %%
df_combined['swap'].value_counts()
# Out:
# Hayır    12553
# Diğer     5464
# Evet      2215
# Name: swap, dtype: int64

# %%
mapper_swap = {
    'Evet': 1,
    'Diğer': 2,
    'Hayır': 3
}

df_combined['swap'] = df_combined['swap'].map(mapper_swap)
df_combined['swap'] = df_combined['swap'].astype('int64')

# %%
df_combined['student_single'].fillna('Diğer',inplace=True)

# %%
df_combined['student_single'].value_counts()
# Out:
# Evet     11249
# Diğer     8983
# Name: student_single, dtype: int64

# %%
df_combined['facade'] = df_combined['facade'].fillna('Güney')

mapper = {
    'Güney,': 'Güney',
    'Kuzey,': 'Kuzey',
    'Doğu,': 'Doğu'
}
df_combined['facade'] = df_combined['facade'].map(mapper).fillna(df_combined['facade'])

# %%
df_combined['facade'].value_counts()
# Out:
# Güney    15216
# Kuzey     3082
# Doğu      1457
# Batı       477
# Name: facade, dtype: int64

# %%
df_combined['fuel_type'].fillna('Diğer',inplace=True)
# df_combined = df_combined[df_combined.fuel_type=='Doğalgaz']

# %%
df_combined['fuel_type'].value_counts()
# Out:
# Doğalgaz      18479
# Diğer          1538
# Elektrik        186
# Kömür-Odun       18
# Akaryakıt        11
# Name: fuel_type, dtype: int64

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20232 entries, 0 to 25118
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    20232 non-null  object
#  1   district                20232 non-null  object
#  2   neighborhood            20232 non-null  object
#  3   prop_type               20232 non-null  object
#  4   rooms                   20232 non-null  int64
#  5   living_room             20232 non-null  int64
#  6   price                   20232 non-null  int64
#  7   last_edit               20232 non-null  int64
#  8   area                    20232 non-null  float64
#  9   prop_floor              20232 non-null  int64
#  10  building_age            20232 non-null  int64
#  11  heating_type            20232 non-null  int64
#  12  building_floors         20232 non-null  int64
#  13  credit_availability     20232 non-null  object
#  14  furniture_availability  20232 non-null  object
#  15  bathrooms               20232 non-null  int64
#  16  building_type           20232 non-null  object
#  17  building_status         20232 non-null  int64
#  18  usage_status            20232 non-null  object
#  19  deed                    20232 non-null  object
#  20  swap                    20232 non-null  int64
#  21  student_single          20232 non-null  object
#  22  facade                  20232 non-null  object
#  23  fuel_type               20232 non-null  object
# dtypes: float64(1), int64(11), object(12)
# memory usage: 3.9+ MB

# %%
df_combined.to_pickle("./data/clean.pkl")
